# %% [markdown]
# <a href="https://colab.research.google.com/github/ricospeloacaso/python_para_investimentos/blob/master/01_Python_para_Investimentos_com_Google_Colab_Obtendo_cota%C3%A7%C3%B5es_do_Yahoo_Finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ricos pelo Acaso

# %% [markdown]
# Link do vídeo: https://youtu.be/7GGrt3-rRH8

# %% [markdown]
# # Bibliotecas

# %% [markdown]
# >Instalando o YFinance

# %%
#!pip install yfinance --upgrade --no-cache-dir

# %% [markdown]
# >Importando as Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %% [markdown]
# >Importando o YFinance e sobrescrevendo os métodos do `pandas_datareader`

# %%
import yfinance as yf

import pandas_datareader.data as pdr

#yf.pdr_override()  # Certifique-se de que o módulo está corretamente instalado

# %% [markdown]
# # Obtendo os dados do mercado

# %% [markdown]
# >Baixando as cotações do Yahoo Finance para o Índice Bovespa

# %%
#data = web.get_data_yahoo('^BVSP')
#data = yf.download("^BVSP", start="2020-01-01", end="2023-01-01")
data = yf.download("^BVSP")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# >Exibindo as cotações mais antigas

# %%
data.head()
# Out:
# Price           Close       High        Low       Open Volume
# Ticker          ^BVSP      ^BVSP      ^BVSP      ^BVSP  ^BVSP
# Date
# 1993-04-27  24.500000  25.400000  24.500000  24.799999      0
# 1993-04-28  24.299999  24.600000  23.700001  24.500000      0
# 1993-04-29  23.700001  24.799999  23.700001  24.299999      0
# 1993-04-30  24.100000  24.200001  23.700001  23.700001      0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000      0

# %% [markdown]
# >Exibindo as cotações mais recentes

# %%
data.tail()
# Out:
# Price               Close         High           Low           Open    Volume
# Ticker              ^BVSP        ^BVSP         ^BVSP          ^BVSP     ^BVSP
# Date
# 2025-05-20  140110.000000  140244.0000  138966.00000  139636.000000   9650800
# 2025-05-21  137881.000000  140109.0000  137538.00000  140109.000000  10150400
# 2025-05-22  137273.000000  138837.0000  137088.00000  137881.000000  13223200
# 2025-05-23  137824.000000  137824.0000  134997.00000  137273.000000  10682600
# 2025-05-26  138141.953125  138799.6875  137794.96875  137823.984375         0

# %% [markdown]
# >Plotando o gráfico com o preços de fechamento do Índice Bovespa

# %%
data["Close"].plot(figsize=(22,8));
