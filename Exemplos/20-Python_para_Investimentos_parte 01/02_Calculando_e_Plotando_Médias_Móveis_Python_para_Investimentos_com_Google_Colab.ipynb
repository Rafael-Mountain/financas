# %% [markdown]
# <a href="https://colab.research.google.com/github/ricospeloacaso/python_para_investimentos/blob/master/02_Calculando_e_Plotando_M%C3%A9dias_M%C3%B3veis_Python_para_Investimentos_com_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ricos pelo Acaso

# %% [markdown]
# Link para o vídeo: https://youtu.be/BBomKv3NFNc

# %% [markdown]
# # 1. Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

#!pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
# yf.pdr_override()

# %% [markdown]
# # Obtendo os dados do mercado

# %%
#ibov = web.get_data_yahoo('VALE3.SA', start='2010-05-03', end='2013-03-01')
data = yf.download('VALE3.SA', start='2010-05-03', end='2013-03-01')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker       VALE3.SA   VALE3.SA   VALE3.SA   VALE3.SA VALE3.SA
# Date
# 2010-05-03  23.279499  24.085501  23.256985  23.986439     4100
# 2010-05-04  22.225849  23.054365  22.194330  23.031852  6558200
# 2010-05-05  22.779688  23.009330  21.847607  22.063742  6082000
# 2010-05-06  22.455488  23.166932  21.253240  22.514025  6939000
# 2010-05-07  22.378933  22.851727  21.915143  22.649100  4755800

# %%
data.tail()
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker       VALE3.SA   VALE3.SA   VALE3.SA   VALE3.SA VALE3.SA
# Date
# 2013-02-22  17.351818  17.954176  17.298383  17.847307  7438800
# 2013-02-25  17.429541  17.599560  17.288666  17.400394  5109000
# 2013-02-26  17.779295  17.852162  17.206083  17.327526  4874600
# 2013-02-27  17.973610  17.973610  17.458690  17.871598  3909200
# 2013-02-28  18.362225  18.537103  17.633565  17.672428  7847000

# %%
data['MA21'] = data['Open'].rolling(21).mean()
data['MA200'] = data['Open'].rolling(200).mean()
data[['Open','MA21','MA200']].plot(label='VALE',figsize=(22,6))
# Out:
# <Axes: xlabel='Date'>

# %%
data_fatiado = data[data.index.year == 2011]
data_fatiado[['Open']].plot(label='VALE',figsize=(22,6))
plt.legend()

# %%
data_fatiado = data[(data.index.year >= 2008) & (data.index.year <= 2015)]
data_fatiado["Close"].plot(figsize=(22,8), label="Tick")
plt.legend()

# %%
data_fatiado = data[data.index.month == 12]
data_fatiado.tail(50)
# Out:
# Price           Close       High        Low       Open   Volume       MA21  \
# Ticker       VALE3.SA   VALE3.SA   VALE3.SA   VALE3.SA VALE3.SA
# Date
# 2010-12-15  25.575926  25.913636  25.575926  25.837089  2473800  24.997641
# 2010-12-16  25.553411  25.846094  25.476865  25.665982  2226400  25.059822
# 2010-12-17  25.620949  25.711003  25.400311  25.611943  2921400  25.109781
# 2010-12-20  25.440842  25.801066  25.440842  25.792060  2207500  25.165959
# 2010-12-21  25.751537  25.913639  25.575928  25.598442  2562800  25.206913
# 2010-12-22  25.679497  25.769553  25.526401  25.738034  1659300  25.260304
# 2010-12-23  25.598444  25.778557  25.593942  25.697506  1456800  25.316696
# 2010-12-27  24.868984  25.553411  24.868984  25.553411  3026600  25.349931
# 2010-12-28  24.648350  24.990562  24.558293  24.954539  2335900  25.369657
# 2010-12-29  24.819458  24.945538  24.666363  24.765425  2680300  25.392386
# 2010-12-30  24.914019  25.220208  24.819458  24.950040  3486800  25.420475
# ...

# %%
data_fatiado = data[data.index.day == 14]
data_fatiado.tail(50)
# Out:
# Price           Close       High        Low       Open    Volume       MA21  \
# Ticker       VALE3.SA   VALE3.SA   VALE3.SA   VALE3.SA  VALE3.SA
# Date
# 2010-05-14  22.018713  22.468993  21.973684  22.419462   3208400        NaN
# 2010-06-14  21.712521  22.221336  21.622464  22.041225   2522100  21.423486
# 2010-07-14  19.888887  19.969938  19.641233  19.969938   1654300  20.820324
# 2010-09-14  21.523403  21.861113  21.419839  21.703516   2831200  21.683362
# 2010-10-14  24.202576  24.553794  24.090006  24.130531   3305000  22.986173
# 2010-12-14  25.972178  26.318894  25.922646  26.098255   1950700  24.939963
# 2011-01-14  26.998814  27.093372  26.670109  26.791685   2793000  25.863250
# 2011-02-14  25.913643  26.066738  25.418335  25.418335   2407700  26.168370
# 2011-03-14  23.864862  23.864862  23.365051  23.603699   2864600  25.114069
# 2011-04-14  23.367693  23.449717  23.021371  23.107951   3970000  23.839326
# ...
